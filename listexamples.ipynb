# %% [markdown]
# # Lists in Python
# We can declare lists by assigning them to variables. The elements of data are held between square brackets and separated by commas.

# %%
fruits = ["grapes","apples"]

# %%
print(fruits)
# Out:
# ['grapes', 'apples']

# %%
print(fruits[0])
# Out:
# grapes

# %%
print("changed")
